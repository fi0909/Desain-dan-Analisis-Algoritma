# %% [markdown]
# <a href="https://colab.research.google.com/github/fi0909/Desain-dan-Analisis-Algoritma/blob/main/Pertemuan_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib as plt

vertices = range(0,10)
edges = [(7,2),(2,3),(7,4),(4,5),(7,3),(7,5),(1,6),(1,7),(2,8),(2,9)]
node_f =[1,4,3,8,9]
node_nf =[2,5,6,7]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
def fraud(node_f,node_nf):
  nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
  nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
  nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
  labels={}
  labels[1]= r'1 NF'
  labels[2]= r'2 F'
  labels[3]= r'3 NF'
  labels[4]= r'4 NF'
  labels[5]= r'5 F'
  labels[6]= r'6 F'
  labels[7]= r'7 F'
  labels[8]= r'8 NF'
  labels[9]= r'9 NF'

  nx.draw_networkx_labels(G,pos,labels,font_size=16)

fraud(node_f,node_nf)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=[1,4,3,8,9],label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=[2,5,6,7],label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels= {}
labels[1]= r'1 NF'
labels[2]= r'2 F'
labels[3]= r'3 NF'
labels[4]= r'4 NF'
labels[5]= r'5 F'
labels[6]= r'6 F'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'

labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}

# %%
vertices = range(0,11)
edges = [ (1,2),
          (1,7),
          (2,3),
          (2,6),
          (3,4),
          (3,6),
          (6,5),
          (7,6),
          (7,8),
          (7,9),
          (7,10),
          (8,9),
          ]
node_f =[1,7,10,4,5]
node_nf =[2,3,6,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='g',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='r',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 NF'
labels[3]= r'3 NF'
labels[4]= r'4 F'
labels[5]= r'5 F'
labels[6]= r'6 NF'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos
dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(-1.0, -0.5162926119092126, '0 (0)'),
#  1: Text(0.17859719239183341, 0.1436016483842812, '1 (2)'),
#  2: Text(0.2263599624423095, -0.015851814068643173, '2 (3)'),
#  3: Text(0.16601327560523418, -0.18313994048285293, '3 (3)'),
#  4: Text(0.13455506097427747, -0.3555638031051609, '4 (1)'),
#  5: Text(0.32851031920917345, -0.09499147808257648, '5 (1)'),
#  6: Text(0.14509273216524857, -0.019815536837974403, '6 (4)'),
#  7: Text(0.022693810171405066, 0.1860889085777536, '7 (5)'),
#  8: Text(0.022749701494911432, 0.3620453675302645, '8 (2)'),
#  9: Text(-0.07233744221312159, 0.3340226615025381, '9 (2)'),
#  10: Text(-0.15223461224127163, 0.15989659849158327, '10 (1)')}

# %%
vertices = range(0,13)
edges = [ (1,2),
          (1,3),
          (2,3),
          (2,12),
          (3,4),
          (4,6),
          (4,5),
          (4,7),
          (7,8),
          (5,8),
          (8,9),
          (6,9),
          (3,11),
          (3,10),
          (12,11),
          (12,13),
          ]
node_f =[1,2,3,11,10,12]
node_nf =[13,4,5,6,7,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 F'
labels[3]= r'3 F'
labels[4]= r'4 NF'
labels[5]= r'5 NF'
labels[6]= r'6 NF'
labels[7]= r'7 NF'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'
labels[11]= r'11 F'
labels[12]= r'12 F'
labels[13]= r'13 NF'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(0.9999999999999999, -0.1018310834767611, '0 (0)'),
#  1: Text(0.013148019925945376, -0.22963283786154767, '1 (2)'),
#  2: Text(-0.08267582423696689, -0.2733165800922511, '2 (3)'),
#  3: Text(-0.04799938914880032, -0.10193002628617288, '3 (5)'),
#  4: Text(-0.054807729774862673, 0.15488589719124812, '4 (4)'),
#  5: Text(-0.16096885084022353, 0.29041345151235026, '5 (2)'),
#  6: Text(0.04390298164142031, 0.31105956412652935, '6 (2)'),
#  7: Text(-0.07426772119645686, 0.2960596102210172, '7 (2)'),
#  8: Text(-0.1020842501432527, 0.4158992413554179, '8 (3)'),
#  9: Text(0.020928317429814425, 0.45760575815892324, '9 (2)'),
#  10: Text(0.10123112845706601, -0.1031317522925521, '10 (1)'),
#  11: Text(-0.17567178585647197, -0.23009385976474278, '11 (2)'),
#  12: Text(-0.20099275856411947, -0.37735643735664465, '12 (3)'),
#  13: Text(-0.2797421376930916, -0.5086309454348139, '13 (1)')}
