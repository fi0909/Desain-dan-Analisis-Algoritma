# %% [markdown]
# <a href="https://colab.research.google.com/github/fi0909/Desain-dan-Analisis-Algoritma/blob/main/Pertemuan_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib as plt

vertices = range(0,10)
edges = [(7,2),(2,3),(7,4),(4,5),(7,3),(7,5),(1,6),(1,7),(2,8),(2,9)]
node_f =[1,4,3,8,9]
node_nf =[2,5,6,7]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
def fraud(node_f,node_nf):
  nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
  nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
  nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
  labels={}
  labels[1]= r'1 NF'
  labels[2]= r'2 F'
  labels[3]= r'3 NF'
  labels[4]= r'4 NF'
  labels[5]= r'5 F'
  labels[6]= r'6 F'
  labels[7]= r'7 F'
  labels[8]= r'8 NF'
  labels[9]= r'9 NF'

  nx.draw_networkx_labels(G,pos,labels,font_size=16)

fraud(node_f,node_nf)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=[1,4,3,8,9],label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=[2,5,6,7],label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels= {}
labels[1]= r'1 NF'
labels[2]= r'2 F'
labels[3]= r'3 NF'
labels[4]= r'4 NF'
labels[5]= r'5 F'
labels[6]= r'6 F'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'

labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}

# %%
vertices = range(0,11)
edges = [ (1,2),
          (1,7),
          (2,3),
          (2,6),
          (3,4),
          (3,6),
          (6,5),
          (7,6),
          (7,8),
          (7,9),
          (7,10),
          (8,9),
          ]
node_f =[1,7,10,4,5]
node_nf =[2,3,6,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 NF'
labels[3]= r'3 NF'
labels[4]= r'4 F'
labels[5]= r'5 F'
labels[6]= r'6 NF'
labels[7]= r'7 F'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos
dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(-0.1345285848797146, 1.0, '0 (0)'),
#  1: Text(-0.09969763065567062, -0.07207289970477941, '1 (2)'),
#  2: Text(0.0013679682223798008, 0.05577177001201478, '2 (3)'),
#  3: Text(0.11334248884036842, 0.15168402734184624, '3 (3)'),
#  4: Text(0.17225531480687287, 0.31908585237765497, '4 (1)'),
#  5: Text(0.2693402438849244, -0.07018670613594549, '5 (1)'),
#  6: Text(0.09195750140787246, -0.04623679542180026, '6 (4)'),
#  7: Text(-0.06321518977460207, -0.2365150230104232, '7 (5)'),
#  8: Text(-0.005883608959530582, -0.4025701914723112, '8 (2)'),
#  9: Text(-0.10486093072801868, -0.41056465075860815, '9 (2)'),
#  10: Text(-0.24007757216488093, -0.2883953832276483, '10 (1)')}

# %%
vertices = range(0,13)
edges = [ (1,2),
          (1,3),
          (2,3),
          (2,12),
          (3,4),
          (4,6),
          (4,5),
          (4,7),
          (7,8),
          (5,8),
          (8,9),
          (6,9),
          (3,11),
          (3,10),
          (12,11),
          (12,13),
          ]
node_f =[1,2,3,11,10,12]
node_nf =[13,4,5,6,7,8,9]

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G,pos,nodelist=node_f,label=True,node_color='r',node_size=1300)
nx.draw_networkx_nodes(G,pos,nodelist=node_nf,label=True ,node_color='g',node_size=1300)
nx.draw_networkx_edges(G,pos,edges,width =3,alpha=0.5,edge_color='b')
labels={}
labels[1]= r'1 F'
labels[2]= r'2 F'
labels[3]= r'3 F'
labels[4]= r'4 NF'
labels[5]= r'5 NF'
labels[6]= r'6 NF'
labels[7]= r'7 NF'
labels[8]= r'8 NF'
labels[9]= r'9 NF'
labels[10]= r'10 F'
labels[11]= r'11 F'
labels[12]= r'12 F'
labels[13]= r'13 NF'

def calculate_dos(node):
  dos = 0
  for neighbor in G.neighbors(node):
    if labels[neighbor] != labels[node]:
        dos+=1
  return dos

dos_values ={node : calculate_dos(node) for node in G.nodes()}
labels = {node : f'{node} ({dos_values[node]})' for node in G.nodes()}
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {0: Text(-0.5272980846070269, -1.0, '0 (0)'),
#  1: Text(0.19729264698459276, 0.22532637439756198, '1 (2)'),
#  2: Text(0.31207688565656694, 0.19325019189402734, '2 (3)'),
#  3: Text(0.1559753424631084, 0.08194245084814346, '3 (5)'),
#  4: Text(-0.12498547562498832, 0.032996776941934265, '4 (4)'),
#  5: Text(-0.2788779654474145, -0.009574280396265095, '5 (2)'),
#  6: Text(-0.309485456148931, 0.12187890216628969, '6 (2)'),
#  7: Text(-0.2566697710423829, -0.10403572610516404, '7 (2)'),
#  8: Text(-0.40438403323426364, -0.055714306696752224, '8 (3)'),
#  9: Text(-0.4660333909310658, 0.07665985078821749, '9 (2)'),
#  10: Text(0.2054229225567311, -0.07528776100062574, '10 (1)'),
#  11: Text(0.36023578906560116, 0.08903033803733403, '11 (2)'),
#  12: Text(0.4878068317500295, 0.1883682864100406, '12 (3)'),
#  13: Text(0.6489237585594431, 0.23515890271525827, '13 (1)')}
